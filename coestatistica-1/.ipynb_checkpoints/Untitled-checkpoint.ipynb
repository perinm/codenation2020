# %%
import pandas as pd
import json

# %%
df = pd.read_csv("desafio1.csv")

# %%
df
# Out:
#       RowNumber                                        id  \
# 0             1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1             2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2             3  774bc378f787438c9c7594e536787d07a097a54b
# 3             4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4             5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
# ...         ...                                       ...
# 6995       6996  3e607c788c09d6e1f99cc50575e471fee41a322a
# 6996       6997  2afdb40334e1bef3451f3db02b12c255c7a9ff57
# 6997       6998  6a0589e36c12f95a8d3678b460519ed654fe0a3e
# 6998       6999  c042de909a1fb157765c84c3278d8e6500807367
# 6999       7000  cdce83890ea1d7b64b2caaaea76f499cb5dfe684
#
#                                      sobrenome  pontuacao_credito  \
# 0     6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1     48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2     f2b29d5d934de615812b697132e767dea0f1e9e2                502
# ...

# %%
grupo = df.groupby("estado_residencia").pontuacao_credito.agg(["mean","median","std"])

# %%
grupo = df.groupby("estado_residencia").agg(mediana=("pontuacao_credito","median"),
                                            media=("pontuacao_credito","mean"),
                                            desvio_padrao=("pontuacao_credito","std")
                                           )

# %%
grupo
# Out:
#                    mediana       media  desvio_padrao
# estado_residencia
# PR                     650  648.961294      98.607186
# RS                     650  651.105143      95.136598
# SC                     653  649.537653      97.233493

# %%
dici = grupo.to_dict('index')

# %%
dici
# Out:
# {'PR': {'mediana': 650,
#   'media': 648.9612940496822,
#   'desvio_padrao': 98.60718591309755,
#   'moda': 850},
#  'RS': {'mediana': 650,
#   'media': 651.1051428571428,
#   'desvio_padrao': 95.1365984138358,
#   'moda': 850},
#  'SC': {'mediana': 653,
#   'media': 649.5376527422563,
#   'desvio_padrao': 97.23349279343314,
#   'moda': 850}}

# %%
for i in df.estado_residencia.unique():
    dici[i]["moda"]=int(df[df["estado_residencia"]==i].pontuacao_credito.mode()[0])

# %%
dici
# Out:
# {'PR': {'mediana': 650,
#   'media': 648.9612940496822,
#   'desvio_padrao': 98.60718591309755,
#   'moda': 850},
#  'RS': {'mediana': 650,
#   'media': 651.1051428571428,
#   'desvio_padrao': 95.1365984138358,
#   'moda': 850},
#  'SC': {'mediana': 653,
#   'media': 649.5376527422563,
#   'desvio_padrao': 97.23349279343314,
#   'moda': 850}}

# %%
with open('submission.json', 'w') as fp:
    json.dump(dici, fp,sort_keys=True, indent=4)
